# %% [markdown]
# ## Data Loading + Libraries Import

# %%
# %pip install pandas
# %pip install numpy
# %pip install matplotlib
# %pip install seaborn
# %pip install scikit-learn
# %pip install IPython
# Out:
# Requirement already satisfied: pandas in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (2.4.2)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from seaborn) (2.4.2)
# Requirement already satisfied: pandas>=1.2 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from scikit-learn) (2.4.2)
# Requirement already satisfied: scipy>=1.10.0 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: IPython in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (9.10.0)
# Requirement already satisfied: decorator>=4.3.2 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from IPython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from IPython) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from IPython) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from IPython) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from IPython) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from IPython) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from IPython) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from IPython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from IPython) (5.14.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from jedi>=0.18.1->IPython) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from pexpect>4.3->IPython) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython) (0.6.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->IPython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->IPython) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/alicemusso/PycharmProjects/PDAI_Project/.venv/lib/python3.12/site-packages (from stack_data>=0.6.0->IPython) (0.2.3)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import  LabelEncoder, StandardScaler
from pathlib import Path
from IPython.display import Image

path = "../power_nap_vs_coffee_effectiveness_dataset.csv"
df = pd.read_csv(path) #df = nome standardizzato per DataFrame

df.shape, df.head(), df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   participant_id                 500 non-null    int64
#  1   age                            500 non-null    int64
#  2   occupation                     500 non-null    str
#  3   sleep_hours_previous_night     500 non-null    float64
#  4   intervention_type              500 non-null    str
#  5   intervention_duration_minutes  500 non-null    int64
#  6   alertness_score_before         500 non-null    int64
#  7   alertness_score_after          500 non-null    int64
#  8   productivity_rating            500 non-null    int64
#  9   mood_rating                    500 non-null    int64
#  10  side_effects                   293 non-null    str
# dtypes: float64(1), int64(7), str(3)
# memory usage: 43.1 KB
# ((500, 11),
#     participant_id  age            occupation  sleep_hours_previous_night  \
#  0               1   24  Working Professional                         5.4
#  1               2   37               Student                         5.6
#  2               3   32  Working Professional                         4.4
#  3               4   28               Student                         6.9
#  4               5   25  Working Professional                         4.7
#
#    intervention_type  intervention_duration_minutes  alertness_score_before  \
#  0         Power Nap                             15                      62
#  1         Power Nap                             30                      67
#  2            Coffee                             30                      44
#  3            Coffee                             30                      59
#  4         Power Nap                             30                      40
#
#     alertness_score_after  productivity_rating  mood_rating side_effects
#  0                     77                    5           10   Grogginess
#  1                     83                    6            5          NaN
#  2                     52                    2            5      Anxiety
#  3                     70                    4            6        Crash
#  4                     58                    3            6   Grogginess  ,
#  None)

# %% [markdown]
# La prima cosa che notiamo, è che ci sono 207 missing values su 500 nella colonna Side Effects. Per fare una prova per l'esame, intepretiamo questi valori come "nessun side effect" e quindi non sono valori mancanti ma informativi. Se fosse un dataset vero, sarebbe da chiedere a chi ha creato il dataset e chiedere conferma se sia effettivamente così.

# %% [markdown]
# ## Data Preprocessing

# %%
# Missing
(df.isna().mean().sort_values(ascending=False) * 100).round(1)

# Duplicati (participant_id dovrebbe essere unico)
df.duplicated().sum(), df["participant_id"].duplicated().sum()

# Valori strani / range rapidi
df.describe(include="all").T
# Out:
#                                count unique         top freq    mean  \
# participant_id                 500.0    NaN         NaN  NaN   250.5
# age                            500.0    NaN         NaN  NaN  30.928
# occupation                       500      3     Student  190     NaN
# sleep_hours_previous_night     500.0    NaN         NaN  NaN  6.0586
# intervention_type                500      2      Coffee  261     NaN
# intervention_duration_minutes  500.0    NaN         NaN  NaN    22.3
# alertness_score_before         500.0    NaN         NaN  NaN   57.38
# alertness_score_after          500.0    NaN         NaN  NaN   71.23
# productivity_rating            500.0    NaN         NaN  NaN   5.374
# mood_rating                    500.0    NaN         NaN  NaN   5.422
# side_effects                     293      3  Grogginess  120     NaN
#
#                                       std   min     25%    50%     75%    max
# participant_id                 144.481833   1.0  125.75  250.5  375.25  500.0
# age                              8.147612  18.0    24.0   31.0    38.0   44.0
# occupation                            NaN   NaN     NaN    NaN     NaN    NaN
# sleep_hours_previous_night       1.136842   4.0     5.1    6.1     7.0    8.0
# intervention_type                     NaN   NaN     NaN    NaN     NaN    NaN
# intervention_duration_minutes    5.654551  15.0    15.0   20.0    25.0   30.0
# alertness_score_before           9.943306  40.0    49.0   58.0    65.0   74.0
# alertness_score_after           11.420067  46.0    62.0   72.0   79.25   97.0
# productivity_rating              2.842232   1.0     3.0    5.0     8.0   10.0
# mood_rating                      2.908752   1.0     3.0    5.0     8.0   10.0
# side_effects                          NaN   NaN     NaN    NaN     NaN    NaN

# %% [markdown]
# Abbiamo deciso di utilizzare la funzione describe per ottenere informazioni su tutte le righe del dataframe. Poiché il dataset contiene sia variabili categoriali sia numeriche, è normale aspettarsi la presenza di diversi valori NaN in alcune metriche.
#
# In particolare, i NaN attesi sono:
# - Variabili numeriche → NaN in: unique, top, freq (metriche proprie delle variabili categoriali)
# - Variabili categoriali → NaN in: mean, std, min e nei percentili (metriche proprie delle variabili numeriche)

# %% [markdown]
# ## Pulizia dati

# %% [markdown]
# In questa fase abbiamo deciso di:
# - togliere i duplicati. Nel caso di questo dataset, non è necessario, in quanto non sono presenti duplicati, ma è buona pratica fare comunque questo tipo di operazione
# - sostituire i NaN con la stringa "None", dato che abbiamo deciso di interpretarli come "assenza di effetti collaterali"
# - abbiamo deciso di convertire le variabili string "Intervention type", "Side effects" e "Occupation" al datatype "category", così da renderle più facilmente analizzabili

# %%
df = df.drop_duplicates(subset=["participant_id"]).copy()
df["side_effects"] = df["side_effects"].fillna("None")

# Categorie
df["intervention_type"] = df["intervention_type"].astype("category")
df["occupation"] = df["occupation"].astype("category")
df["side_effects"] = df["side_effects"].astype("category")
#df["intervention_duration_minutes"] = df["intervention_duration_minutes"].astype("category")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   participant_id                 500 non-null    int64
#  1   age                            500 non-null    int64
#  2   occupation                     500 non-null    category
#  3   sleep_hours_previous_night     500 non-null    float64
#  4   intervention_type              500 non-null    category
#  5   intervention_duration_minutes  500 non-null    int64
#  6   alertness_score_before         500 non-null    int64
#  7   alertness_score_after          500 non-null    int64
#  8   productivity_rating            500 non-null    int64
#  9   mood_rating                    500 non-null    int64
#  10  side_effects                   500 non-null    category
# dtypes: category(3), float64(1), int64(7)
# memory usage: 32.9 KB

# %% [markdown]
# In questo modo, grazie alla funzione info, abbiamo conferma che non sono più presenti valori NaN nel dataset e che le variabili di tipo stringa sono state correttamente convertite in tipo category.

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ## Feature engeneering
#
# Abbiamo deciso che potesse essere interessante inserire una nuova variabile, alertness_delta. Per ogni partecipante, questa variabile restituisce un valore float calcolato come differenza tra alertness_after e alertness_before. In questo modo, possiamo verificare facilmente l'efficacia dei vari tipi di intervento.Infatti, se l'alertness delta è positivo, significa che l'intervento ha portato il partecipante a essere più riposato. Se invece l'allertness delta è negativo, significa che l'intervento ha portato il partecipante a sentirsi più stanco.

# %%
#Calcolo alertness_delta
df["alertness_delta"] = df["alertness_score_after"] - df["alertness_score_before"]

#Controllo se l'intervento ha funzionato
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   participant_id                 500 non-null    int64
#  1   age                            500 non-null    int64
#  2   occupation                     500 non-null    category
#  3   sleep_hours_previous_night     500 non-null    float64
#  4   intervention_type              500 non-null    category
#  5   intervention_duration_minutes  500 non-null    int64
#  6   alertness_score_before         500 non-null    int64
#  7   alertness_score_after          500 non-null    int64
#  8   productivity_rating            500 non-null    int64
#  9   mood_rating                    500 non-null    int64
#  10  side_effects                   500 non-null    category
#  11  alertness_delta                500 non-null    int64
# dtypes: category(3), float64(1), int64(8)
# memory usage: 36.8 KB

# %% [markdown]
# ## Architettura dataframe
#
# Il processo di gestione dei dati è stato strutturato in diverse fasi, creando versioni differenti del dataframe a seconda dell’obiettivo analitico (EDA o ML). Questo approccio consente di mantenere separati i diversi step dell’analisi, evitando errori metodologici (come il data leakage).
#
# I dataframe che abbiamo creato sono:
# - **df**: dati puliti non scalati, utilizzati per analisi descrittive
# - **df_clean_scaled**: dati scalati per analisi dati e identificazione outlier
# - **df_encoded**: dataframe in qui viene fatto l'encoding delle variabili categoriali su dati puliti, senza fare scaling. Il motivo per cui non abbiamo fatto encoding su df_clean_scaled è che, in fase di modellazione, bisogna usare i dati non scalati, per evitare il leakage di informazioni del test set in fase di training.
# - **df_encoded_corr**: dataframe con encoding + scaling, che usiamo solo al fine di fare l'analisi della  correlazione fra le varie features

# %%
Image(filename="../dataset_schema.png")

# %% [markdown]
# ## Scaling

# %% [markdown]
# In questo blocco creiamo una copia del dataset df contenente le variabili numeriche standardizzate, così da renderle confrontabili tra loro nonostante le differenze nei valori originali. La standardizzazione verrà inoltre utilizzata per la costruzione dei grafici, in modo da rendere più facilmente osservabili outliers, eventuali differenze nelle medie e nelle distribuzioni.
#
# Per le analisi EDA, abbiamo deciso di non standardizzare la durata dell’intervento, poiché si tratta di variabili discrete che trattiamo come categoriali, in quanto rappresentano intervalli di tempo piuttosto che una durata temporale precisa.

# %%
scaler = StandardScaler()

# Standardizza le colonne specifiche
cols_to_scale = ["sleep_hours_previous_night", "alertness_delta", "productivity_rating", "mood_rating", "alertness_score_before", "alertness_score_after", "age"]
df_clean_scaled = df.copy()
df_clean_scaled[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])

print(df_clean_scaled.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   participant_id                 500 non-null    int64
#  1   age                            500 non-null    float64
#  2   occupation                     500 non-null    category
#  3   sleep_hours_previous_night     500 non-null    float64
#  4   intervention_type              500 non-null    category
#  5   intervention_duration_minutes  500 non-null    int64
#  6   alertness_score_before         500 non-null    float64
#  7   alertness_score_after          500 non-null    float64
#  8   productivity_rating            500 non-null    float64
#  9   mood_rating                    500 non-null    float64
#  10  side_effects                   500 non-null    category
#  11  alertness_delta                500 non-null    float64
# dtypes: category(3), float64(7), int64(2)
# memory usage: 36.8 KB
# None

# %% [markdown]
# ## Encoding

# %% [markdown]
# In questo blocco di codice facciamo encoding sulle colonne categoriali:
# 1) La variabile Side_Effects riceve un semplice label encoding in quanto è scelta come variabile target, ed è quindi esclusa dalla feature matrix
# 2) Le variabili Intervention_Type e Occupation ricevono un Dummy encoding in quanto sono categoriali e incluse nella feature matrix
# 3) La variabile "intervention_duration_minutes" ha subito un trattamento particolare. Nonostante sia presentata come variabile numerica, in realtà è una variabile categoriale ordinale con 4 categorie di durata (15/20/25/30 min).

# %%
le = LabelEncoder()

df_encoded = df.copy()

#We apply simple label encoding to the "side_effects" since it's categorical and target
df_encoded["side_effects"] = le.fit_transform(df["side_effects"])

#We apply one-hot econding to the "intervention_type" and "occupation" since they are categorical and not target
df_encoded["intervention_type"] = le.fit_transform(df["intervention_type"])
df_encoded = pd.get_dummies(df_encoded, columns=["occupation"])
print(df_encoded.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   participant_id                   500 non-null    int64
#  1   age                              500 non-null    int64
#  2   sleep_hours_previous_night       500 non-null    float64
#  3   intervention_type                500 non-null    int64
#  4   intervention_duration_minutes    500 non-null    int64
#  5   alertness_score_before           500 non-null    int64
#  6   alertness_score_after            500 non-null    int64
#  7   productivity_rating              500 non-null    int64
#  8   mood_rating                      500 non-null    int64
#  9   side_effects                     500 non-null    int64
#  10  alertness_delta                  500 non-null    int64
#  11  occupation_Freelancer            500 non-null    bool
#  12  occupation_Student               500 non-null    bool
#  13  occupation_Working Professional  500 non-null    bool
# dtypes: bool(3), float64(1), int64(10)
# memory usage: 44.6 KB
# None

# %%
df_encoded_corr = df_encoded.copy()
df_encoded_corr[cols_to_scale] = scaler.fit_transform(df_encoded[cols_to_scale])

#NB: scaler e cols_to_scale sono quelli definiti in precedenza.
df_encoded_corr.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   participant_id                   500 non-null    int64
#  1   age                              500 non-null    float64
#  2   sleep_hours_previous_night       500 non-null    float64
#  3   intervention_type                500 non-null    int64
#  4   intervention_duration_minutes    500 non-null    int64
#  5   alertness_score_before           500 non-null    float64
#  6   alertness_score_after            500 non-null    float64
#  7   productivity_rating              500 non-null    float64
#  8   mood_rating                      500 non-null    float64
#  9   side_effects                     500 non-null    int64
#  10  alertness_delta                  500 non-null    float64
#  11  occupation_Freelancer            500 non-null    bool
#  12  occupation_Student               500 non-null    bool
#  13  occupation_Working Professional  500 non-null    bool
# dtypes: bool(3), float64(7), int64(4)
# memory usage: 44.6 KB

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# ## Feature Correlation
#
# In questa sezione vogliamo osservare se ci sono feature correlate fra di loro, in modo tale da eliminare eventuali collinearità. Creiamo quindi una matrice di correlazione, che poi decidiamo di rendere in maniera grafica con un clustermap.

# %%
df_encoded_corr = df_encoded_corr.drop('participant_id', axis=1, inplace=False)
corr_matrix = df_encoded_corr.corr()
corr_matrix
# Out:
#                                       age  sleep_hours_previous_night  \
# age                              1.000000                    0.030162
# sleep_hours_previous_night       0.030162                    1.000000
# intervention_type               -0.000882                    0.038056
# intervention_duration_minutes   -0.000748                   -0.054677
# alertness_score_before          -0.041219                   -0.005307
# alertness_score_after           -0.012809                    0.023071
# productivity_rating             -0.016748                   -0.030861
# mood_rating                     -0.003704                    0.038625
# side_effects                     0.006059                    0.030667
# alertness_delta                  0.052263                    0.062705
# occupation_Freelancer           -0.033454                   -0.034388
# occupation_Student              -0.008768                    0.027450
# occupation_Working Professional  0.041856                    0.005146
#
#                                  intervention_type  \
# age                                      -0.000882
# sleep_hours_previous_night                0.038056
# intervention_type                         1.000000
# intervention_duration_minutes             0.017932
# alertness_score_before                    0.037558
# alertness_score_after                     0.300425
# productivity_rating                       0.009327
# mood_rating                              -0.034251
# side_effects                              0.505889
# alertness_delta                           0.606239
# occupation_Freelancer                    -0.028205
# occupation_Student                        0.001485
# occupation_Working Professional           0.026067
#
#                                  intervention_duration_minutes  \
# age                                                  -0.000748
# sleep_hours_previous_night                           -0.054677
# intervention_type                                     0.017932
# intervention_duration_minutes                         1.000000
# alertness_score_before                                0.026661
# alertness_score_after                                 0.018481
# productivity_rating                                  -0.096026
# mood_rating                                          -0.051210
# side_effects                                         -0.051868
# alertness_delta                                      -0.010717
# occupation_Freelancer                                -0.071758
# occupation_Student                                    0.045954
# occupation_Working Professional                       0.022505
#
#                                  alertness_score_before  \
# age                                           -0.041219
# sleep_hours_previous_night                    -0.005307
# intervention_type                              0.037558
# intervention_duration_minutes                  0.026661
# alertness_score_before                         1.000000
# alertness_score_after                          0.897609
# productivity_rating                            0.001839
# mood_rating                                    0.017587
# side_effects                                  -0.031097
# alertness_delta                                0.060964
# occupation_Freelancer                          0.037145
# occupation_Student                            -0.064793
# occupation_Working Professional                0.030948
#
#                                  alertness_score_after  productivity_rating  \
# age                                          -0.012809            -0.016748
# sleep_hours_previous_night                    0.023071            -0.030861
# intervention_type                             0.300425             0.009327
# intervention_duration_minutes                 0.018481            -0.096026
# alertness_score_before                        0.897609             0.001839
# alertness_score_after                         1.000000             0.000864
# productivity_rating                           0.000864             1.000000
# mood_rating                                   0.033631             0.013838
# side_effects                                  0.100272             0.023331
# alertness_delta                               0.494693            -0.001671
# occupation_Freelancer                         0.057389            -0.098140
# occupation_Student                           -0.085849             0.047801
# occupation_Working Professional               0.033006             0.046410
#
#                                  mood_rating  side_effects  alertness_delta  \
# age                                -0.003704      0.006059         0.052263
# sleep_hours_previous_night          0.038625      0.030667         0.062705
# intervention_type                  -0.034251      0.505889         0.606239
# intervention_duration_minutes      -0.051210     -0.051868        -0.010717
# alertness_score_before              0.017587     -0.031097         0.060964
# alertness_score_after               0.033631      0.100272         0.494693
# productivity_rating                 0.013838      0.023331        -0.001671
# mood_rating                         1.000000      0.051640         0.041482
# side_effects                        0.051640      1.000000         0.288369
# alertness_delta                     0.041482      0.288369         1.000000
# occupation_Freelancer               0.010717      0.012828         0.056718
# occupation_Student                 -0.020107     -0.050409        -0.066654
# occupation_Working Professional     0.010397      0.039810         0.013721
#
#                                  occupation_Freelancer  occupation_Student  \
# age                                          -0.033454           -0.008768
# sleep_hours_previous_night                   -0.034388            0.027450
# intervention_type                            -0.028205            0.001485
# intervention_duration_minutes                -0.071758            0.045954
# alertness_score_before                        0.037145           -0.064793
# alertness_score_after                         0.057389           -0.085849
# productivity_rating                          -0.098140            0.047801
# mood_rating                                   0.010717           -0.020107
# side_effects                                  0.012828           -0.050409
# alertness_delta                               0.056718           -0.066654
# occupation_Freelancer                         1.000000           -0.510077
# occupation_Student                           -0.510077            1.000000
# occupation_Working Professional              -0.449007           -0.539522
#
#                                  occupation_Working Professional
# age                                                     0.041856
# sleep_hours_previous_night                              0.005146
# intervention_type                                       0.026067
# intervention_duration_minutes                           0.022505
# alertness_score_before                                  0.030948
# alertness_score_after                                   0.033006
# productivity_rating                                     0.046410
# mood_rating                                             0.010397
# side_effects                                            0.039810
# alertness_delta                                         0.013721
# occupation_Freelancer                                  -0.449007
# occupation_Student                                     -0.539522
# occupation_Working Professional                         1.000000

# %%
sns.set(font_scale=0.8)
plt.figure(figsize=(16,9))
sns.clustermap(corr_matrix,annot=True,fmt=".2f",figsize=(20,14)) # Plot the correlation matrix as a hierarchically-clustered heatmap.
plt.title("Correlation Between Features")
plt.show()

# %% [markdown]
# Osserviamo che le uniche features che hanno una correlazione significativa (>0.80 o < -0.80) sono l'alertness_score_before e l'alertness_score_after: per questo motivo, in seguito, verrà solamente considerata la variabile alertness_delta

# %% [markdown]
# _______________________________________________________________________

# %% [markdown]
# ## Outlier detection

# %% [markdown]
# Vogliamo individuare gli outlier nelle colonne numeriche del dataframe standardizzato (df_clean_scaled). Per questo motivo, abbiamo creato una funzione che calcoli in automatico interquartili e outlier per ogni colonna numerica, restituendo una maschera booleana. Successivamente, abbiamo visualizzato la distribuzione delle varibili numeriche con dei boxplot.

# %%
num_cols = df_clean_scaled.select_dtypes(include="number").columns.drop("participant_id", errors="ignore")

def iqr_outlier_mask(s: pd.Series, k: float = 1.5) -> pd.Series:
    q1 = s.quantile(0.25)
    q3 = s.quantile(0.75)
    iqr = q3 - q1
    lower = q1 - k * iqr
    upper = q3 + k * iqr
    return (s < lower) | (s > upper)
#Ho fatto sta cosa per il discorso di Vandin dell'essere pythonici. Forse questo potrebbe essere messo in uno script a parte e chiamato importando lo script con tutti i metodi (ALICE PLS CHIEDI A VANDIN QUANDO VAI A LEZIONE <3)

#qui applico la mia nuova maschera a tutte le colonne numeriche e creo un DataFrame con i risultati
outlier_mask = pd.DataFrame({c: iqr_outlier_mask(df_clean_scaled[c]) for c in num_cols})

# riepilogo: quanti outlier per colonna
outlier_summary = (
    outlier_mask.sum()
    .to_frame("n_outliers")
    .assign(pct_outliers=lambda x: (x["n_outliers"] / len(df) * 100).round(2))
    .sort_values("n_outliers", ascending=False)
)

outlier_summary
# Out:
#                                n_outliers  pct_outliers
# age                                     0           0.0
# sleep_hours_previous_night              0           0.0
# intervention_duration_minutes           0           0.0
# alertness_score_before                  0           0.0
# alertness_score_after                   0           0.0
# productivity_rating                     0           0.0
# mood_rating                             0           0.0
# alertness_delta                         0           0.0

# %%
cols_to_boxplot = ["age", "sleep_hours_previous_night", "alertness_delta", "productivity_rating", "mood_rating"]

data = [df_clean_scaled[c].dropna().values for c in cols_to_boxplot]

plt.figure(figsize=(12, 5))
plt.boxplot(data, tick_labels=cols_to_boxplot, showfliers=True)
plt.xticks(rotation=45, ha="right")
plt.title("Boxplot variabili numeriche")
plt.tight_layout()
plt.show()

# %% [markdown]
# Osserviamo che non abbiamo ottenuto outliers.

# %% [markdown]
# _________________________________________________________________________________

# %% [markdown]
# ## Analisi esplorative + grafichetti

# %% [markdown]
# **PARTE 1**: La distribuzione della variabile target
#
# In questa fase vogliamo osservare la distribuzione dei side effects nella popolazione. Infatti, è importante vedere se la distribuzione della variabile target è più o meno bilanciata. Queste informazioni sono importanti per le fasi successive, in quanto saranno utili per addestrare il modello che predirrà la comparsa di effetti collaterali, in particolar modo servono per scegliere il tipo di errore che dovrà minimizzare il modello.

# %%
# Calcola le percentuali
side_effects_pct = df['side_effects'].value_counts(normalize=True) * 100

# Crea il barplot
ax = side_effects_pct.plot(kind='bar', figsize=(10, 6))
ax.set_ylabel('Percentuale (%)')
ax.set_xlabel('Side Effects')
ax.set_title('Distribuzione Side Effects (%)')
plt.xticks(rotation=45)

# Aggiungi valori sulle barre
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height:.1f}%',
                xy=(p.get_x() + p.get_width()/2, height),
                ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# Osserviamo che l'assenza di effetti collaterali è nettamente più presente nella popolazione rispetto agli altri effetti. Abbiamo deciso quindi di osservare la distribuzione del tipo di intervento e dei side effects.

# %%
total = len(df)  # Totale generale
side_effects = ["None", "Grogginess", "Anxiety", "Crash"]

# Calcola i conteggi per Coffee
coffee_counts = (
    df[df["intervention_type"] == "Coffee"]["side_effects"]
    .value_counts()
    .reindex(side_effects, fill_value=0)
)

# Calcola i conteggi per Power Nap
nap_counts = (
    df[df["intervention_type"] == "Power Nap"]["side_effects"]
    .value_counts()
    .reindex(side_effects, fill_value=0)
)

# Converti in percentuali sul TOTALE GENERALE (non sul totale del gruppo)
coffee_pct = (coffee_counts / total) * 100
nap_pct = (nap_counts / total) * 100

# Dataframe unico
plot_df = pd.DataFrame({
    "Coffee": coffee_pct,
    "Power Nap": nap_pct
})

ax = plot_df.plot(kind="bar")

plt.title("Side effects (%) by intervention - % of total observations")
plt.xlabel("Side effect")
plt.ylabel("Percentuale sul totale")
plt.ylim(0, plot_df.max().max() + 5)  # Un po' di spazio in più
plt.xticks(rotation=0)

# Etichette percentuali
for p in ax.patches:
    h = p.get_height()
    ax.annotate(f"{h:.1f}%",
                (p.get_x() + p.get_width()/2, h),
                ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# **PARTE 2**: Intervention type x Alertness
#
# Per questa seconda parte dell'analisi abbiamo deciso utilizzare l'alertness delta come variabile dipendente, usando il tipo di intervento come indipendente. Questo perché ci interessa verificare quale tipo di intervento sia più riposante, ovvero quale tipo intervento ha un alertness delta maggiore. Per questo motivo verifichiamo inizialmente la distribuzione dei tipi di intervento; in secondo luogo, abbiamo deciso osservare la varianza dell'allertness delta considerato il tipo di intervento.

# %%
ax = sns.countplot(data=df, x="intervention_type")

# Calcola il totale per le percentuali
total = len(df)

# Modifica l'asse Y per mostrare percentuali
y_ticks = ax.get_yticks()
ax.set_yticklabels([f'{int(y*100/total)}%' for y in y_ticks])
ax.set_ylabel('Percentuale (%)')

# Aggiungi le percentuali sopra le barre
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{100*height/total:.1f}%',
                xy=(p.get_x() + p.get_width()/2, height),
                ha='center', va='bottom')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/cq/g6pj_0v94dx4wjrqw_ywbydw0000gn/T/ipykernel_11470/90622165.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([f'{int(y*100/total)}%' for y in y_ticks])

# %%
#descrittive per alertness_delta raggruppato per intervento
df.groupby("intervention_type")["alertness_delta"].describe().round(2)
# Out:
#                    count   mean   std   min   25%   50%   75%   max
# intervention_type
# Coffee             261.0  10.93  3.86   5.0   7.0  11.0  15.0  17.0
# Power Nap          239.0  17.04  4.18  10.0  14.0  17.0  21.0  24.0

# %%
#Creo i miei dati d'interesse per il boxplot
data = [
    df_clean_scaled.loc[df_encoded["intervention_type"]==0, "alertness_delta"],
    df_clean_scaled.loc[df_encoded["intervention_type"]==1, "alertness_delta"]
]

#Disegno il Boxplot (non ho idea di cosa sia metà di queste cose, grazie ChatGPT)
plt.boxplot(data, tick_labels=["Coffee","Power Nap"])
plt.ylabel("Alertness Δ (after - before)")
plt.title("Alertness improvement by intervention")
plt.show()

# %% [markdown]
# Sembra dal boxplot che il power nap migliori l'alertness, mentre il caffè peggiori l'alertness. Questo è abbastanza sorprendente, almeno per il senso comune.

# %% [markdown]
# **PARTE 2.1**: Intervention Type x Intervention duration
#
# Per vedere se fosse rilevante per l'allertness delta anche la durata dell'intervento, abbiamo deciso di studiare quest'ultima come seconda variabile dipendente, usando il tipo di intervento come indipendente.

# %%
df_t15 = df_clean_scaled[df_clean_scaled["intervention_duration_minutes"] == 15]["alertness_delta"]
df_t20 = df_clean_scaled[df_clean_scaled["intervention_duration_minutes"] == 20]["alertness_delta"]
df_t25 = df_clean_scaled[df_clean_scaled["intervention_duration_minutes"] == 25]["alertness_delta"]
df_t30 = df_clean_scaled[df_clean_scaled["intervention_duration_minutes"] == 30]["alertness_delta"]

datasets = {
    "15 min": df_t15,
    "20 min": df_t20,
    "25 min": df_t25,
    "30 min": df_t30,
}

durations = sorted(df_clean_scaled["intervention_duration_minutes"].unique())

fig, axes = plt.subplots(2, 2, figsize=(15, 8), sharex=True, sharey=True)
axes = axes.ravel()

for ax, duration in zip(axes, durations):
    data_duration = df_clean_scaled[df_clean_scaled["intervention_duration_minutes"] == duration]

    if len(data_duration) > 0:  # Verifica che ci siano dati
        sns.histplot(
            data=data_duration,
            x="alertness_delta",
            hue="intervention_type",
            bins=20,
            kde=True,
            stat="count",
            ax=ax,
            palette=["#FF6B6B", "#4ECDC4"]
        )
        ax.set_title(f"Alertness Δ — {duration} min")
        ax.set_xlabel("alertness_delta")
        ax.set_ylabel("Frequenza")
    else:
        ax.text(0.5, 0.5, f"No data for {duration} min", ha="center", va="center")
        ax.set_title(f"Alertness Δ — {duration} min")

plt.tight_layout()
plt.show()

# %% [markdown]
# Osservando la distribuzione dei grafici, abbiamo scoperto che la distribuzione dell'alertness delta non è neanche lontanamente normale... Per questo decidiamo di studiare la mediana e fare i boxplot

# %%
pivot = df_clean_scaled.pivot_table(
    index="intervention_duration_minutes",
    columns="intervention_type",
    values="alertness_delta",
    aggfunc="median"
).sort_index()

pivot.plot(marker="o")
plt.ylabel("Median alertness Δ")
plt.title("Median alertness improvement by duration")
plt.show()

# %% [markdown]
# Sembra che ci sia una CHIARISSIMA differenza nei livelli di alertness fra caffe e power nap. Questo si vedeva anche dal boxplot, ma da qui si può vedere che per la duration time di 25 minuti ci sia la maggiore differenza di Delta-awareness (pari a 1.6).
#
# Intanto facciamo i boxplot per delta alertness e intervention duration, dato che funzionano meglio per le distribuzioni non normali. Osservando il boxplot che studia l'alertness delta a seconda della durata dell'intervento, si vede che il delta non cambia. Questo ci ha spinto a creare anche dei boxplot che studiano sempre alertness delta per durata dell'intervento, ma divisi per tipo di intervento.

# %%
durations = [15, 20, 25, 30]
df_duration = [df_clean_scaled[(df_clean_scaled["intervention_duration_minutes"]==d)]["alertness_delta"]
    for d in durations]

plt.boxplot(df_duration, tick_labels=["15 minutes","20 minutes", "25 minutes", "30 minutes"])
plt.ylabel("Alertness Δ")
plt.title("Alertness improvement by duration")
plt.show()

# %%
durations = [15, 20, 25, 30]

# Coffee
coffee_data = [
    df_clean_scaled[(df_clean_scaled["intervention_type"]=="Coffee") & (df_clean_scaled["intervention_duration_minutes"]==d)]["alertness_delta"]
    for d in durations
]

# Power Nap
nap_data = [
    df_clean_scaled[(df_clean_scaled["intervention_type"]=="Power Nap") & (df_clean_scaled["intervention_duration_minutes"]==d)]["alertness_delta"]
    for d in durations
]

fig, axes = plt.subplots(1, 2, figsize=(12,6))

# Boxplot Coffee
axes[0].boxplot(coffee_data, tick_labels=[f"{d} min" for d in durations])
axes[0].set_title("Coffee")
axes[0].set_ylabel("Alertness Δ (std)")

# Boxplot Power Nap
axes[1].boxplot(nap_data, tick_labels=[f"{d} min" for d in durations])
axes[1].set_title("Power Nap")
axes[1].set_ylabel("Alertness Δ")

plt.suptitle("Alertness improvement by intervention duration")
plt.show()

# %% [markdown]
# Comunque si vede che questo dataset non è fatto da italiani, bere un caffè in mezz'ora dovrebbe essere illegale. Comunque possiamo concludere che, considerando la mediana, i power nap di 25 minuti sono più efficaci, mentre PER L'AMOR DI DIO se si deve prendere il caffè, NON BISOGNA BERLO in 25 minuti. A parte tutto, sembra che la durata dell'intervento non sia una variabile troppo rilevante per l'altertness delta.
#
# Un'altra cosa su cui eravamo curiosi era osservare l'alertness delta per il tipo di side effects: ci si aspetterebbe che l'alertness delta fosse minore per i side effects "grogginess" e "crash", mentre invece ci si aspetta un livello di alertness maggiore per l'ansia.

# %%
side_effects_list = ["None", "Grogginess", "Anxiety", "Crash"]

# Coffee
coffee_data = [
    df_clean_scaled[(df_clean_scaled["intervention_type"]=="Coffee") & (df_clean_scaled["side_effects"]==d)]["alertness_delta"]
    for d in side_effects_list
]

# Power Nap
nap_data = [
    df_clean_scaled[(df_clean_scaled["intervention_type"]=="Power Nap") & (df_clean_scaled["side_effects"]==d)]["alertness_delta"]
    for d in side_effects_list
]

fig, axes = plt.subplots(1, 2, figsize=(12,6))

# Boxplot Coffee
axes[0].boxplot(coffee_data, tick_labels=[f"{d}" for d in side_effects_list])
axes[0].set_title("Coffee")
axes[0].set_ylabel("Alertness Δ (std)")

# Boxplot Power Nap
axes[1].boxplot(nap_data, tick_labels=[f"{d}" for d in side_effects_list])
axes[1].set_title("Power Nap")
axes[1].set_ylabel("Alertness Δ")

plt.suptitle("Alertness improvement by intervention duration")
plt.show()

# %% [markdown]
# Un risultato interessante è che l’alertness delta risulta più alto in presenza di ansia (il che è abbastanza prevedibile). Al contrario, si osservano differenze minime tra la condizione senza effetti collaterali e quella di crash, un risultato, invece, inatteso. Inoltre la media tra assenza di effetti collaterali e grogginess sia comparabile, ma quest’ultima presenta una distribuzione più spostata verso valori negativi, che ha senso.

# %% [markdown]
# ## NEW CSV PRODUCTION

# %% [markdown]
# In questa parte riassumiamo i dataset che abbiamo creato e infine, salviamo in un file csv, il file che vogliamo usare per analisi future. Si può scegliere se creare questo file, sovrascrivendo eventuali dataframe già presenti, oppure no.

# %%
df.shape, df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   participant_id                 500 non-null    int64
#  1   age                            500 non-null    int64
#  2   occupation                     500 non-null    category
#  3   sleep_hours_previous_night     500 non-null    float64
#  4   intervention_type              500 non-null    category
#  5   intervention_duration_minutes  500 non-null    category
#  6   alertness_score_before         500 non-null    int64
#  7   alertness_score_after          500 non-null    int64
#  8   productivity_rating            500 non-null    int64
#  9   mood_rating                    500 non-null    int64
#  10  side_effects                   500 non-null    category
#  11  alertness_delta                500 non-null    int64
# dtypes: category(4), float64(1), int64(7)
# memory usage: 33.9 KB
# ((500, 12), None)

# %%
df_clean_scaled.shape, df_clean_scaled.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   participant_id                 500 non-null    int64
#  1   age                            500 non-null    float64
#  2   occupation                     500 non-null    category
#  3   sleep_hours_previous_night     500 non-null    float64
#  4   intervention_type              500 non-null    category
#  5   intervention_duration_minutes  500 non-null    category
#  6   alertness_score_before         500 non-null    float64
#  7   alertness_score_after          500 non-null    float64
#  8   productivity_rating            500 non-null    float64
#  9   mood_rating                    500 non-null    float64
#  10  side_effects                   500 non-null    category
#  11  alertness_delta                500 non-null    float64
# dtypes: category(4), float64(7), int64(1)
# memory usage: 33.9 KB
# ((500, 12), None)

# %%
df_encoded.shape, df_encoded.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   participant_id                   500 non-null    int64
#  1   age                              500 non-null    int64
#  2   sleep_hours_previous_night       500 non-null    float64
#  3   intervention_type                500 non-null    int64
#  4   intervention_duration_minutes    500 non-null    category
#  5   alertness_score_before           500 non-null    int64
#  6   alertness_score_after            500 non-null    int64
#  7   productivity_rating              500 non-null    int64
#  8   mood_rating                      500 non-null    int64
#  9   side_effects                     500 non-null    int64
#  10  alertness_delta                  500 non-null    int64
#  11  occupation_Freelancer            500 non-null    bool
#  12  occupation_Student               500 non-null    bool
#  13  occupation_Working Professional  500 non-null    bool
# dtypes: bool(3), category(1), float64(1), int64(9)
# memory usage: 41.3 KB
# ((500, 14), None)

# %%
df_encoded_corr.shape, df_encoded_corr.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              500 non-null    float64
#  1   sleep_hours_previous_night       500 non-null    float64
#  2   intervention_type                500 non-null    int64
#  3   intervention_duration_minutes    500 non-null    category
#  4   alertness_score_before           500 non-null    float64
#  5   alertness_score_after            500 non-null    float64
#  6   productivity_rating              500 non-null    float64
#  7   mood_rating                      500 non-null    float64
#  8   side_effects                     500 non-null    int64
#  9   alertness_delta                  500 non-null    float64
#  10  occupation_Freelancer            500 non-null    bool
#  11  occupation_Student               500 non-null    bool
#  12  occupation_Working Professional  500 non-null    bool
# dtypes: bool(3), category(1), float64(7), int64(2)
# memory usage: 37.4 KB
# ((500, 13), None)

# %% [markdown]
# Il seguente blocco pulisce DF_Encoded per prepare il salvataggio di un file .csv preparatorio per la parte di ML

# %%
df_encoded = df_encoded.drop(["alertness_score_before", "alertness_score_after"], axis=1)
df_encoded.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   participant_id                   500 non-null    int64
#  1   age                              500 non-null    int64
#  2   sleep_hours_previous_night       500 non-null    float64
#  3   intervention_type                500 non-null    int64
#  4   intervention_duration_minutes    500 non-null    category
#  5   productivity_rating              500 non-null    int64
#  6   mood_rating                      500 non-null    int64
#  7   side_effects                     500 non-null    int64
#  8   alertness_delta                  500 non-null    int64
#  9   occupation_Freelancer            500 non-null    bool
#  10  occupation_Student               500 non-null    bool
#  11  occupation_Working Professional  500 non-null    bool
# dtypes: bool(3), category(1), float64(1), int64(7)
# memory usage: 33.5 KB

# %%
from pathlib import Path

csv_path = Path("df_encoded.csv")

if csv_path.exists():
    overwrite = input(f"Il file {csv_path} esiste già. Sovrascrivere? (s/n): ")
    if overwrite.lower() != 's':
        print("Operazione annullata.")
    else:
        df_encoded.to_csv(csv_path, index=False)
        print(f"✓ File sovrascritto: {csv_path}")
else:
    df_encoded.to_csv(csv_path, index=False)
    print(f"✓ File salvato: {csv_path}")
# Out:
# Operazione annullata.
